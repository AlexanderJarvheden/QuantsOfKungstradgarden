# %%
import pandas as pd
# Round 1:

# Primary focus: turn these products into profit
products = ["ASH_COATED_OSMIUM", "INTARIAN_PEPPER_ROOT"]

# value of INTARIAN_PEPPER_ROOT is quite steady, but keep in mind that it’s a hardy, slow-growing root
# ASH_COATED_OSMIUM more volatile, it's unpredictability may follow a hidden pattern

# The product limits `ASH_COATED_OSMIUM`: 80, `INTARIAN_PEPPER_ROOT`: 80
limits = {products[0]: 80, products[1]: 80}

path = "Datasets/ROUND1/prices_round_1_day_"
data = []
for t in range(0,-3,-1):
    data.append(pd.read_csv(path+f"{t}"+".csv", delimiter=";"))
df = pd.concat(data)
pd.set_option("display.max_rows", None)
df
# Bonus: Exchange Auction during round 1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/6h/tflctw7s3jb8k6w65jmxt4440000gn/T/ipykernel_8557/2392051269.py in <module>
#      16     data.append(pd.read_csv(path+f"{t}"+".csv", delimiter=";"))
#      17 df = pd.concat(data)
# ---> 18 pd.set_option("display.max_rows", -1)
#      19 df
#      20 # Bonus: Exchange Auction during round 1
#
# ~/miniconda3/envs/venv/lib/python3.7/site-packages/pandas/_config/config.py in __call__(self, *args, **kwds)
#     241
#     242     def __call__(self, *args, **kwds):
# --> 243         return self.__func__(*args, **kwds)
#     244
#     245     @property
#
# ~/miniconda3/envs/venv/lib/python3.7/site-packages/pandas/_config/config.py in _set_option(*args, **kwargs)
#     138         o = _get_registered_option(key)
#     139         if o and o.validator:
# --> 140             o.validator(v)
#     141
#     142         # walk the nested dict
#
# ~/miniconda3/envs/venv/lib/python3.7/site-packages/pandas/_config/config.py in is_nonnegative_int(value)
#     846
#     847     msg = "Value must be a nonnegative integer or None"
# --> 848     raise ValueError(msg)
#     849
#     850
#
# ValueError: Value must be a nonnegative integer or None
